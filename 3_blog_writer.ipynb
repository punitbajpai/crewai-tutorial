# %%
from dotenv import load_dotenv
load_dotenv()
import os

os.environ["LITELLM_LOG"] = "CRITICAL"
os.environ["LITELLM_DISABLE_LOGGING"] = "true"
os.environ["LITELLM_LOG_LEVEL"] = "CRITICAL"

from crewai import LLM
import os

llm  = LLM(model="groq/llama-3.1-8b-instant",temperature=0, provider="groq")

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role = "Research Specialist",
    goal = "Research interesting facts about the topic : {topic}",
    backstory = "You are an expert at finding relevant and factual data.",
    verbose = True,
    llm = llm
)

writer_agent = Agent(
    role = "Creative Writer",
    goal = "Write a short blog summary using the research",
    backstory = "You are skilled at writing engaging summaries based on provided content.",
    verbose = True,
    llm = llm
)

# %%
task1 = Task(
    description = "Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullest list of 3-5 facts",
    agent = research_agent,

)

task2 = Task(
    description = "Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent = writer_agent,
    context = [task1],
)

crew = Crew(
    agents = [research_agent,writer_agent],
    tasks = [task1,task2],
    verbose = True,
)

crew.kickoff(inputs={"topic":"The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3c50d888-d16d-4f79-94fe-0a947edabf87                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  • **Fact 1:** According to a report by BloombergNEF, by 2040, over 50% of new car sales are expected to be     │
# │  electric vehicles (EVs), with the majority of countries having more than 50% of their new car sales being      │
# │  electric. This is due to the decreasing cost of EVs, increasing government incentives, and growing consumer    │
# │  demand for sustainable transportation options.                                                                 │
# │                                                                                                                 │
# │  • **Fact 2:** The International Energy Agency (IEA) predicts that by 2050, there will be over 140 million      │
# │  electric vehicles on the road globally, accounting for around 30% of all new car sales. This will lead to a    │
# │  significant reduction in greenhouse gas emissions from the transportation sector, which currently accounts     │
# │  for around 15% of global emissions.                                                                            │
# │                                                                                                                 │
# │  • **Fact 3:** Solid-state batteries (SSBs) are expected to play a crucial role in the future of electric       │
# │  vehicles. SSBs have the potential to increase the range of EVs by up to 500 miles, reduce charging times to    │
# │  under 10 minutes, and increase safety by eliminating the risk of thermal runaway. Several major automakers,    │
# │  including Volkswagen and Toyota, are already investing heavily in SSB technology.                              │
# │                                                                                                                 │
# │  • **Fact 4:** The European Union has set a target of having at least 50% of new car sales be electric by       │
# │  2035. To achieve this goal, the EU has implemented a range of policies, including tax incentives, subsidies    │
# │  for EV manufacturers, and investments in charging infrastructure. Several European countries, including        │
# │  Norway and the Netherlands, are already leading the way in electric vehicle adoption.                          │
# │                                                                                                                 │
# │  • **Fact 5:** China, the world's largest car market, has set a target of having 50% of new car sales be        │
# │  electric by 2035. To achieve this goal, China has implemented a range of policies, including tax incentives,   │
# │  subsidies for EV manufacturers, and investments in charging infrastructure. China is also investing heavily    │
# │  in the development of electric vehicle technology, including the development of solid-state batteries and      │
# │  other advanced battery technologies.                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ab589bb4-17ce-4cc5-a800-ab014ba88862                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Future of Electric Vehicles: A Sustainable Transportation Revolution**                                   │
# │                                                                                                                 │
# │  As the world continues to grapple with the challenges of climate change, the transportation sector is poised   │
# │  to undergo a significant transformation. Electric vehicles (EVs) are at the forefront of this revolution,      │
# │  with a growing number of countries and automakers investing heavily in the technology. According to a report   │
# │  by BloombergNEF, by 2040, over 50% of new car sales are expected to be electric vehicles, with the majority    │
# │  of countries having more than 50% of their new car sales being electric.                                       │
# │                                                                                                                 │
# │  The International Energy Agency (IEA) predicts that by 2050, there will be over 140 million electric vehicles  │
# │  on the road globally, accounting for around 30% of all new car sales. This will lead to a significant          │
# │  reduction in greenhouse gas emissions from the transportation sector, which currently accounts for around 15%  │
# │  of global emissions. The European Union has set a target of having at least 50% of new car sales be electric   │
# │  by 2035, while China, the world's largest car market, has also set a target of 50% by 2035.                    │
# │                                                                                                                 │
# │  The future of electric vehicles is also being driven by advances in technology, particularly in the            │
# │  development of solid-state batteries (SSBs). SSBs have the potential to increase the range of EVs by up to     │
# │  500 miles, reduce charging times to under 10 minutes, and increase safety by eliminating the risk of thermal   │
# │  runaway. Several major automakers, including Volkswagen and Toyota, are already investing heavily in SSB       │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  As the world transitions to a more sustainable transportation system, governments and automakers must work     │
# │  together to ensure a smooth and efficient transition. This includes investing in charging infrastructure,      │
# │  providing tax incentives and subsidies for EV manufacturers, and promoting consumer awareness and education    │
# │  about the benefits of electric vehicles. With the right policies and technologies in place, the future of      │
# │  electric vehicles looks bright, and we can expect to see a significant reduction in greenhouse gas emissions   │
# │  from the transportation sector in the years to come.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 84c29147-2faf-4787-a14f-25a6566acec9                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw="**The Future of Electric Vehicles: A Sustainable Transportation Revolution**\n\nAs the world continues to grapple with the challenges of climate change, the transportation sector is poised to undergo a significant transformation. Electric vehicles (EVs) are at the forefront of this revolution, with a growing number of countries and automakers investing heavily in the technology. According to a report by BloombergNEF, by 2040, over 50% of new car sales are expected to be electric vehicles, with the majority of countries having more than 50% of their new car sales being electric.\n\nThe International Energy Agency (IEA) predicts that by 2050, there will be over 140 million electric vehicles on the road globally, accounting for around 30% of all new car sales. This will lead to a significant reduction in greenhouse gas emissions from the transportation sector, which currently accounts for around 15% of global emissions. The European Union has set a target of having at least 50% of new car sales be electric by 2035, while China, the world's largest car market, has also set a target of 50% by 2035.\n\nThe future of electric vehicles is also being driven by advances in technology, particularly in the development of solid-state batteries (SSBs). SSBs have the potential to increase the range of EVs by up to 500 miles, reduce charging times to under 10 minutes, and increase safety by eliminating the risk of thermal runaway. Several major automakers, including Volkswagen and Toyota, are already investing heavily in SSB technology.\n\nAs the world transitions to a more sustainable transportation system, governments and automakers must work together to ensure a smooth and efficient transition. This includes investing in charging infrastructure, providing tax incentives and subsidies for EV manufacturers, and promoting consumer awareness and education about the benefits of electric vehicles. With the right policies and technologies in place, the future of electric vehicles looks bright, and we can expect to see a significant reduction in greenhouse gas emissions from the transportation sector in the years to come.", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles.', expected_output='A bullest list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw="• **Fact 1:** According to a report by BloombergNEF, by 2040, over 50% of new car sales are expected to be electric vehicles (EVs), with the majority of countries having more than 50% of their new car sales being electric. This is due to the decreasing cost of EVs, increasing government incentives, and growing consumer demand for sustainable transportation options.\n\n• **Fact 2:** The International Energy Agency (IEA) predicts that by 2050, there will be over 140 million electric vehicles on the road globally, accounting for around 30% of all new car sales. This will lead to a significant reduction in greenhouse gas emissions from the transportation sector, which currently accounts for around 15% of global emissions.\n\n• **Fact 3:** Solid-state batteries (SSBs) are expected to play a crucial role in the future of electric vehicles. SSBs have the potential to increase the range of EVs by up to 500 miles, reduce charging times to under 10 minutes, and increase safety by eliminating the risk of thermal runaway. Several major automakers, including Volkswagen and Toyota, are already investing heavily in SSB technology.\n\n• **Fact 4:** The European Union has set a target of having at least 50% of new car sales be electric by 2035. To achieve this goal, the EU has implemented a range of policies, including tax incentives, subsidies for EV manufacturers, and investments in charging infrastructure. Several European countries, including Norway and the Netherlands,  ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 3c50d888-d16d-4f79-94fe-0a947edabf87                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Future of Electric Vehicles: A Sustainable Transportation Revolution**                     │
# │                                                                                                                 │
# │  As the world continues to grapple with the challenges of climate change, the transportation sector is poised   │
# │  to undergo a significant transformation. Electric vehicles (EVs) are at the forefront of this revolution,      │
# │  with a growing number of countries and automakers investing heavily in the technology. According to a report   │
# │  by BloombergNEF, by 2040, over 50% of new car sales are expected to be electric vehicles, with the majority    │
# │  of countries having more than 50% of their new car sales being electric.                                       │
# │                                                                                                                 │
# │  The International Energy Agency (IEA) predicts that by 2050, there will be over 140 million electric vehicles  │
# │  on the road globally, accounting for around 30% of all new car sales. This will lead to a significant          │
# │  reduction in greenhouse gas emissions from the transportation sector, which currently accounts for around 15%  │
# │  of global emissions. The European Union has set a target of having at least 50% of new car sales be electric   │
# │  by 2035, while China, the world's largest car market, has also set a target of 50% by 2035.                    │
# │                                                                                                                 │
# │  The future of electric vehicles is also being driven by advances in technology, particularly in the            │
# │  development of solid-state batteries (SSBs). SSBs have the potential to increase the range of EVs by up to     │
# │  500 miles, reduce charging times to under 10 minutes, and increase safety by eliminating the risk of thermal   │
# │  runaway. Several major automakers, including Volkswagen and Toyota, are already investing heavily in SSB       │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  As the world transitions to a more sustainable transportation system, governments and automakers must work     │
# │  together to ensure a smooth and efficient transition. This includes investing in charging infrastructure,      │
# │  providing tax incentives and subsidies for EV manufacturers, and promoting consumer awareness and education    │
# │  about the benefits of electric vehicles. With the right policies and technologies in place, the future of      │
# │  electric vehicles looks bright, and we can expect to see a significant reduction in greenhouse gas emissions   │
# │  from the transportation sector in the years to come.                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
